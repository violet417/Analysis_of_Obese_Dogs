# %% [markdown]
# ## 라이브러리 불러오기

# %%
import requests
from bs4 import BeautifulSoup

from tqdm.notebook import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 비만&정상 강아지 크롤링

# %%
headers = {
    'cookie':'HSID=AcYMBNP5KDpcPV84K; SSID=AkuAd8GJ3ZAxT32bv; APISID=6iNwn2frynHyy6_m/A5_Wkewk6yfb0uf8H; SAPISID=0J6EthPr3JhtumiO/ADOP1pqWPjzoofbyC; __Secure-1PAPISID=0J6EthPr3JhtumiO/ADOP1pqWPjzoofbyC; __Secure-3PAPISID=0J6EthPr3JhtumiO/ADOP1pqWPjzoofbyC; SEARCH_SAMESITE=CgQItJYB; SID=QwhoWfxX95JnoGesLzaayQ_SkItlVxMpp9fDicSPTCx1S90l7m1DnAqpCd7_zFFCufhrOQ.; __Secure-1PSID=QwhoWfxX95JnoGesLzaayQ_SkItlVxMpp9fDicSPTCx1S90laYI3IJdVqxbu9-B7rb2V3Q.; __Secure-3PSID=QwhoWfxX95JnoGesLzaayQ_SkItlVxMpp9fDicSPTCx1S90lL6SXlcOfY4vJUy01B-MXVQ.; OTZ=6778478_20_20__20_; AEC=AakniGPcdGPT_NSas2CNXWeXOt_HtqyLP-vFQVB4DL1rrHTior6j4qve6vs; 1P_JAR=2022-11-22-23; DV=c8Ytx1LyP69QUOUcLYCoi44LdccbShge9TXKlwa5UAAAAODb1J3c88oZTQAAAPCSFA-qpoSSKgAAAKaqsXzyEc3TEAAAAA; UULE=a+cm9sZTogMQpwcm9kdWNlcjogMTIKdGltZXN0YW1wOiAxNjY5MTYwNzk0NjUzMDAwCmxhdGxuZyB7CiAgbGF0aXR1ZGVfZTc6IDM3NTM5OTIzOAogIGxvbmdpdHVkZV9lNzogMTI3MDUwNzU3Mgp9CnJhZGl1czogMTMwMzA0OS40OTM2ODI3MzA1CnByb3ZlbmFuY2U6IDYK; NID=511=CqMMJcSk-h6u3wPdQTTetvcnXF-6aJnu5knDaBhZ9KHKuTcBS1p4l46amvbwMeI7_5qb3fW0cgJN5-BTr8NaQA7otWEgAFpWOkpWnrCOhBTUG9hTtMwM9zxAuPPXiXSd7g8hKPhZl9RhOht3XKlorBbd8-Ioo1woKH9ZS7PeQ9ahht6nLXpe4GgUlSb0ccjkB1xXbHQsG4Sin4TGI5QqXAUeWkSjbciw2Eh7UpNbnn52KxgXmp2jxzR8FIRGqMjytRjlIPxyurxZgOY; SIDCC=AIKkIs2n260eycVAD1NzVuosTM--kXp8usDC9B6vGl_A6iwlb69NVMSbiU2QybONpIvR0z5nDV0; __Secure-1PSIDCC=AIKkIs0jrfjJEW8gHr0_33oKNkKOFRlcpPFKLL0zNsawCH9v3_sKwjx-xisddd7usbl4jcAM8P8; __Secure-3PSIDCC=AIKkIs2a9di66lkbUw6MYQilxJaEDErc2wtvCjHiEA_DCf2V-myTmwdVvmLYKGCkPmkPNXsgOLI',
    'referer':'https://www.google.com/search?q=fat+welsh+corgi&biw=1552&bih=833&gbv=1&tbm=isch&sxsrf=ALiCzsaO96PKIRgVrpBgD3ilSUblaFtFkw:1669160913515&ei=0V99Y6KHH6qNseMPmOmhuA8&start=40&sa=N',
    'user-agent':'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Mobile Safari/537.36'
    }

# %%
url = 'https://www.google.com/search?q=fat+welsh+corgi&bih=1010&biw=1244&gbv=1&tbm=isch&sxsrf=ALiCzsby7qjC9A2LdkzGRa0ltlxkKoGVrA:1669118357543&ei=lbl8Y6bEIJbj2roP552S2AQ&start=0&sa=N#'

resp = requests.get(url,headers = headers)
resp
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(resp.content, 'lxml')
img_tags = soup.select('img.SjCsie')
print(len(img_tags))

for idx, img_tag in enumerate(img_tags):
    img_src = img_tag['src']
    resp_img = requests.get(img_src)

    img = resp_img.content

    with open('/content/drive/강아지_{:02}.jpg'.format(idx+1), 'wb') as f:
        f.write(img)
# Out:
# 20
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-6d28414a62f4> in <module>
#       9     img = resp_img.content
#      10
# ---> 11     with open('/content/drive/강아지_{:02}.jpg'.format(idx+1), 'wb') as f:
#      12         f.write(img)
#
# OSError: [Errno 95] Operation not supported: '/content/drive/강아지_01.jpg'

# %%
for i in tqdm(range(30), desc='페이지'):
    # i = 0, 1, 2, 3
    # start = 0, 20, 40, 60
    start = 20*i
    url = 'https://www.google.com/search?q=fat+poodle&gbv=1&tbm=isch&sxsrf=ALiCzsaN1BkVBH1lA-S55eSOUShflXHQoQ:1669484257126&ei=4U6CY8ijB7HL2roPoaO1sAI&start={}&sa=N'.format(start)
    resp = requests.get(url,headers = headers)
    
    soup = BeautifulSoup(resp.content, 'lxml')
    img_tags = soup.select('img.SjCsie')
    # print(len(img_tags))
    # break
    for idx, img_tag in tqdm(enumerate(img_tags), desc='이미지/페이지'):
        img_src = img_tag['src']
        resp_img = requests.get(img_src)

        img = resp_img.content

        with open('/content/fat_poodle_{:03}.jpg'.format(start+idx+1), 'wb') as f:
            f.write(img)
# Out:
# 페이지:   0%|          | 0/30 [00:00<?, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]

# %%
for i in tqdm(range(30), desc='페이지'):
    # i = 0, 1, 2, 3
    # start = 0, 20, 40, 60
    start = 20*i
    url = 'https://www.google.com/search?q=fat+maltese&gbv=1&tbm=isch&sxsrf=ALiCzsZ3mLncBObEQ-YYQoDoy__leaZ22Q:1669484633749&ei=WVCCY6OpLcSm2roPwr-ekAU&start={}&sa=N'.format(start)
    resp = requests.get(url,headers = headers)
    
    soup = BeautifulSoup(resp.content, 'lxml')
    img_tags = soup.select('img.SjCsie')
    # print(len(img_tags))
    # break
    for idx, img_tag in tqdm(enumerate(img_tags), desc='이미지/페이지'):
        img_src = img_tag['src']
        resp_img = requests.get(img_src)

        img = resp_img.content

        with open('/content/fat_mal_{:03}.jpg'.format(start+idx+1), 'wb') as f:
            f.write(img)
# Out:
# 페이지:   0%|          | 0/30 [00:00<?, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]

# %%
for i in tqdm(range(30), desc='페이지'):
    # i = 0, 1, 2, 3
    # start = 0, 20, 40, 60
    start = 20*i
    url = 'https://www.google.com/search?q=fat+shiba&biw=1552&bih=833&gbv=1&tbm=isch&sxsrf=ALiCzsZWkJzWZnGYugrRjxf2lQsBGp2TnA:1669300420273&ei=xIB_Y9ilEMbj2roPqaqcwAs&start={}&sa=N'.format(start)
    resp = requests.get(url,headers = headers)
    
    soup = BeautifulSoup(resp.content, 'lxml')
    img_tags = soup.select('img.SjCsie')
    # print(len(img_tags))
    # break
    for idx, img_tag in tqdm(enumerate(img_tags), desc='이미지/페이지'):
        img_src = img_tag['src']
        resp_img = requests.get(img_src)

        img = resp_img.content

        with open('/content/drive/MyDrive/img/image/fat_shiba1_{:03}.jpg'.format(start+idx+1), 'wb') as f:
            f.write(img)
# Out:
# 페이지:   0%|          | 0/30 [00:00<?, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
# 이미지/페이지: 0it [00:00, ?it/s]
